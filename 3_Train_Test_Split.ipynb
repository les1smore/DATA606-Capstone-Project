# %% [markdown]
# <a href="https://colab.research.google.com/github/les1smore/DATA606-Capstone-Project/blob/main/3_Train_Test_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train-test split

# %%
from sklearn.model_selection import train_test_split, KFold

# %%
# Define X and Y
X = data.drop('Have_Diabetes', axis=1)
y = data.Have_Diabetes

# Split the train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, test_size=.3, random_state=1000)

# %%
X_train.describe().T
# Out:
#                                           count      mean        std  min  \
# Good Health                            221097.0  0.815787   0.387659  0.0
# Health Coverage                        221097.0  3.619389   3.833746  0.0
# High Blood Pressure                    221097.0  0.410485   0.491923  0.0
# High Cholesterol                       221097.0  0.503688   0.499988  0.0
# CHD-MI                                 221097.0  0.096673   0.295512  0.0
# Asthma Status                          221097.0  0.178008   0.479475  0.0
# Diagnosed Arthritis                    221097.0  0.344464   0.475194  0.0
# Race/Ethnicity                         221097.0  1.892549   2.086314  1.0
# BMI Category                           221097.0  2.971356   0.824710  1.0
# Income Category                        221097.0  3.718789   1.450615  1.0
# Smoker Status                          221097.0  3.123733   1.306309  0.0
# Heavy Drinker                          221097.0  0.218628   1.203748  0.0
# ...

# %%
X_train.shape, y_train.shape
# Out:
# ((221097, 33), (221097,))
